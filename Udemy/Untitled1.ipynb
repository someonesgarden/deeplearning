# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
data1 = np.random.normal(0, 0.1,1000)
data2 = np.random.normal(1,0.4,1000)
data3 = 2 + np.random.random(1000) + np.linspace(0,1,1000)
data4 = np.random.normal(3,0.2, 1000)+0.3 * np.sin(np.linspace(0, 20, 1000))

# %%
data = np.vstack([data1,data2,data3,data4]).transpose()

# %%
data
# Out:
# array([[-0.15244646,  0.55594065,  2.33395178,  3.01003465],
#        [-0.0643692 ,  0.38841458,  2.6206964 ,  3.17647159],
#        [-0.11439846,  0.3822347 ,  2.77329356,  2.9076466 ],
#        ...,
#        [ 0.09053495,  1.35241559,  3.55310184,  3.33094109],
#        [ 0.13287111,  0.76991008,  3.87141976,  2.95469082],
#        [ 0.19039682,  0.80833437,  3.40705545,  3.43824556]])

# %%
df = pd.DataFrame(data,columns=["data1","data2","data3","data4"])

# %%
df.head()
# Out:
#       data1     data2     data3     data4
# 0 -0.152446  0.555941  2.333952  3.010035
# 1 -0.064369  0.388415  2.620696  3.176472
# 2 -0.114398  0.382235  2.773294  2.907647
# 3 -0.021717  0.961979  2.229370  3.289354
# 4  0.161206  1.860413  2.819842  2.611198

# %%
df.plot(title="Line Plot")

# %%
plt.plot(df)
plt.title("Line Plot")
plt.legend(['data','data2','data3','data4'])

# %%
_ = df.plot(kind="scatter", x="data1",y="data2", xlim=(-1.5,1.5),ylim=(0,3))

# %%
df.plot()

# %%
gt1 = df['data1'] > 0.1

# %%
piecounts = gt1.value_contents()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-cb6ce8fe3b01> in <module>()
# ----> 1 piecounts = gt1.value_contents()
#
# /usr/local/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value_contents'
